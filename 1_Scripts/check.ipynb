# %%
import time
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup

url = "https://prosettings.net/valorant-pro-settings-gear-list/"


driver = webdriver.Chrome(executable_path="../chromedriver.exe")

driver.maximize_window()
driver.get(url)
driver.execute_script("window.scrollTo(0,10000)")
time.sleep(5)

page = driver.page_source
soup = BeautifulSoup(page,"html.parser")
season_stats = soup.find(id="table_1")

df = pd.read_html(str(season_stats))[0]
df.head(20)

df.to_csv()
# Out:
# C:\Users\parya\AppData\Local\Temp\ipykernel_6028\3664602782.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="../chromedriver.exe")
#          Team       Name                              Mouse      HZ     DPI  \
# 0         FPX      ANGE1        Logitech G Pro X Superlight  1000.0   800.0
# 1         FPX       Shao                  Xtrfy M4 Wireless  1000.0   400.0
# 2         FPX     ardiis        Logitech G Pro X Superlight  1000.0   800.0
# 3     FPX (B)      rhyme                  VAXEE ZYGEN NP-01  1000.0   400.0
# 4         FPX     Zyppan  Logitech G Pro X Superlight Black  1000.0   400.0
# 5         FPX   Suygetsu                          Zowie EC2  1000.0   800.0
# 6   Paper Rex   f0rsakeN        Logitech G Pro X Superlight  1000.0   800.0
# 7   Paper Rex      d4v41        Logitech G Pro X Superlight  1000.0   900.0
# 8   Paper Rex     Jinggg            FinalMouse Starlight 12  1000.0  1600.0
# 9   Paper Rex     Benkai                          Pulsar X2  1000.0   800.0
# 10  Paper Rex  mindfreak                     VAXEE XE White  1000.0   400.0
# 11      OpTic        yay  Logitech G Pro X Superlight Black  1000.0   800.0
# 12      OpTic   crashies            Razer DeathAdder V3 Pro  1000.0   800.0
# 13      OpTic     Victor                      Logitech G703  1000.0   800.0
# 14  OpTic (L)     Marved                 Razer Viper V2 Pro  1000.0   800.0
# 15      OpTic        FNS        Logitech G Pro X Superlight  1000.0   400.0
# 16        DRX       BuZz                           Zowie S2  1000.0   400.0
# 17        DRX       MaKo                          Zowie EC2  1000.0   400.0
# 18        DRX       Zest                          Zowie EC2  1000.0   400.0
# 19        DRX       stax            Razer DeathAdder V3 Pro  1000.0   400.0
#
#     Sensitivity   eDPI  Scoped Sensitivity        Monitor  Monitor HZ  \
# 0         0.500  400.0               1.000    BenQ XL2546       240.0
# 1         0.428  171.0               1.000    BenQ XL2546       240.0
# 2         0.295  236.0               1.140  AOC AG251FZ2E       240.0
# 3         0.500  200.0               1.000    BenQ XL2546       240.0
# 4         0.480  192.0               1.000            NaN         NaN
# 5         0.250  200.0               1.100    BenQ XL2411       144.0
# 6         0.712  569.0               1.000   BenQ XL2546K       240.0
# 7         0.650  585.0               1.000    BenQ XL2546       240.0
# 8         0.200  320.0               1.000   BenQ XL2546K       240.0
# 9         0.250  200.0               0.700   BenQ XL2546K       240.0
# 10        0.500  200.0               0.900   BenQ XL2546K       240.0
# 11        0.270  216.0               1.000    BenQ XL2546       240.0
# 12        0.250  200.0               0.875    BenQ XL2546       144.0
# 13        0.283  226.0               1.000    BenQ XL2546       240.0
# 14        0.306  244.0               1.000    BenQ XL2540       240.0
# 15        0.550  220.0               1.000    BenQ XL2546       240.0
# 16        0.570  228.0               0.700   BenQ XL2546K       240.0
# 17        0.450  180.0               1.000   BenQ XL2546S       240.0
# 18        0.560  224.0               1.000   BenQ XL2546K       240.0
# 19        0.440  176.0               0.800   BenQ XL2546S       240.0
#
#                   GPU Resolution                   Mousepad  \
# 0         RTX 2080 Ti  1920x1080              Razer Strider
# 1      RTX 2080 Super  1920x1080             VAXEE PA Black
# 2            RTX 2080  1920x1080       Artisan Hien FX Soft
# 3            RTX 3080   1280x960    Zowie G-SR-SE Deep Blue
# 4         GTX 1080 Ti  1920x1080        Zowie G-SR-SE Rouge
# 5            GTX 1070  1920x1080       Artisan FX Zero Soft
# 6   GALAX GTX 1080 Ti  1920x1080        Zowie G-SR-SE Rouge
# 7         GTX 1080 Ti   1440x990      SteelSeries QcK Heavy
# 8         RTX 2080 Ti   1280x960       Artisan FX Zero Soft
# 9      RTX 2070 Super   1280x960       Artisan Hien FX Soft
# 10                NaN  1920x1080          VAXEE PA Summer22
# 11           RTX 3090  1920x1080  Artisan Hayate Otsu XSoft
# 12           GTX 1080  1920x1080              Razer Strider
# 13           RTX 2080  1920x1080              Razer Strider
# 14           RTX 3080  1920x1080              Razer Strider
# 15           RTX 3090  1920x1080       Artisan FX Zero Soft
# 16                NaN   1280x960      Xraypad Aqua Control+
# 17                NaN  1920x1080          Razer Gigantus V2
# 18                NaN   1280x960          Razer Gigantus V2
# 19        RTX 2080 Ti  1920x1080      SteelSeries QcK Heavy
#
#                                 Keyboard                   Headset
# 0           Razer BlackWidow X Chroma ME     HyperX Cloud Revolver
# 1                       HyperX Alloy FPS           HyperX Cloud II
# 2   Logitech G Pro X Mechanical Keyboard          Logitech G Pro X
# 3                       Xtrfy K4-RGB TKL           HyperX Cloud II
# 4                                    NaN                       NaN
# 5   Logitech G Pro X Mechanical Keyboard          Logitech G Pro X
# 6              HyperX Alloy Origins Core  Logitech G Pro X Headset
# 7                   HyperX Alloy FPS RGB   Razer HammerHead Pro V2
# 8              HyperX Alloy Origins Core  Logitech G Pro X Headset
# 9                   Ducky One 2 Mini RGB          EPOS H6PRO White
# 10                 Ducky One 2 TKL White                       NaN
# 11                         Wooting 60 HE       Razer BlackShark V2
# 12               Razer Blackwidow V3 TKL       Razer BlackShark V2
# 13               Razer Blackwidow V3 TKL       Razer BlackShark V2
# 14               Razer Blackwidow V3 TKL       Razer BlackShark V2
# 15               Razer BlackWidow V3 Pro       Razer BlackShark V2
# 16                 Razer Huntsman V2 TKL   Razer BlackShark V2 Pro
# 17                     Razer Huntsman V2   Razer BlackShark V2 Pro
# 18                 Razer Huntsman V2 TKL   Razer BlackShark V2 Pro
# 19                 Razer Huntsman V2 TKL   Razer BlackShark V2 Pro
